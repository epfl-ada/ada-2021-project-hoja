# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import random

# %% [markdown]
# # Constants

# %%
COLORS = ["red", "blue", "green", "brown", "purple", "orange", "pink", "yellow", "grey"]

# %% [markdown]
# # Fetch and read data

# %%
population_path = "WPP2019_TotalPopulationBySex.csv"
death_path = "annual-number-of-deaths-by-cause.csv"
cat_death_path = "total-number-of-deaths-by-cause.csv"

# %%
raw_population_df = pd.read_csv(population_path)
raw_population_df
# Out:
#         LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 0           4  Afghanistan      2       Medium  1950     1950.5   4099.243
# 1           4  Afghanistan      2       Medium  1951     1951.5   4134.756
# 2           4  Afghanistan      2       Medium  1952     1952.5   4174.450
# 3           4  Afghanistan      2       Medium  1953     1953.5   4218.336
# 4           4  Afghanistan      2       Medium  1954     1954.5   4266.484
# ...       ...          ...    ...          ...   ...        ...        ...
# 280927    716     Zimbabwe    207  Lower 95 PI  2080     2080.5  10576.533
# 280928    716     Zimbabwe    207  Lower 95 PI  2085     2085.5  10293.349
# 280929    716     Zimbabwe    207  Lower 95 PI  2090     2090.5   9920.336
# 280930    716     Zimbabwe    207  Lower 95 PI  2095     2095.5   9503.711
# 280931    716     Zimbabwe    207  Lower 95 PI  2100     2100.5   9090.075
#
#         PopFemale   PopTotal  PopDensity
# ...

# %%
raw_death_df = pd.read_csv(death_path)
raw_death_df
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 6681     Zimbabwe  ZWE  2013                                          NaN
# 6682     Zimbabwe  ZWE  2014                                          NaN
# 6683     Zimbabwe  ZWE  2015                                          NaN
# 6684     Zimbabwe  ZWE  2016                                          NaN
# 6685     Zimbabwe  ZWE  2017                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# ...

# %%
raw_cat_death_df = pd.read_csv(cat_death_path)
raw_cat_death_df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6463     Zimbabwe  ZWE  2013
# 6464     Zimbabwe  ZWE  2014
# 6465     Zimbabwe  ZWE  2015
# 6466     Zimbabwe  ZWE  2016
# 6467     Zimbabwe  ZWE  2017
#
#       Deaths - Non-communicable diseases - Sex: Both - Age: All Ages (Number)  \
# 0                                          84698.000146
# 1                                          85229.762662
# 2                                          88069.819403
# 3                                          93620.091979
# 4                                          97706.825332
# ...                                                 ...
# 6463                                       43813.657226
# 6464                                       43708.402562
# 6465                                       43853.733855
# ...

# %% [markdown]
# # Preprocess data

# %%
def modify_and_drop_cols(df, rename_cols, drop_cols):
    df = df[df["Year"] > 2007]
    df = df.drop(drop_cols, axis=1)
    cols = list(df.columns)
    for i, col in enumerate(cols):
        if len(col.split(" - ")) > 1:
            rename_cols[col] = col.split(" - ")[1].strip()
    df = df.rename(columns=rename_cols)
    df = df.reset_index(drop=True)
    return df

# %%
def extract_world_data(df):
    df = df[df["Entity"] == "World"]
    df = df.reset_index(drop=True)
    return df

# %%
population_df = raw_population_df[(raw_population_df["Location"] == "World") & (raw_population_df["Time"] > 2007) & (raw_population_df["Time"] < 2018)]
population_df = population_df[["Time", "PopTotal"]].reset_index(drop=True)
population_df = population_df.rename(columns = {"Time": "Year", "PopTotal": "World population"})
population_df["World population"] = population_df["World population"].apply(lambda x: x/1000)
population_df
# Out:
#    Year  World population
# 0  2008       6789.088672
# 1  2009       6872.766988
# 2  2010       6956.823588
# 3  2011       7041.194168
# 4  2012       7125.827957
# 5  2013       7210.582041
# 6  2014       7295.290759
# 7  2015       7379.796967
# 8  2016       7464.021934
# 9  2017       7547.858900

# %%
def divide_values_by_pop(df, cols):
    df = df.copy()
    for col in cols:
        for year in list(population_df["Year"]):
            df.at[year-2008, col] = df[df["Year"] == year][col]/population_df[population_df["Year"] == year]["World population"]
    return df

# %% [markdown]
# ## Total deaths

# %%
raw_columns = raw_death_df.columns
drop_cols = ['Number of executions (Amnesty International)']
rename_cols = {'Terrorism (deaths)': 'Terrorism'}

# %%
death_df = modify_and_drop_cols(raw_death_df, rename_cols, drop_cols)

# %%
death_df
# Out:
#            Entity Code  Year   Meningitis  Lower respiratory infections  \
# 0     Afghanistan  AFG  2008  8387.057275                  26623.480551
# 1     Afghanistan  AFG  2009  7318.273004                  24792.335792
# 2     Afghanistan  AFG  2011  6919.757958                  23115.144836
# 3     Afghanistan  AFG  2012  6631.942601                  22155.754481
# 4     Afghanistan  AFG  2013  6774.892059                  22417.229523
# ...           ...  ...   ...          ...                           ...
# 2373     Zimbabwe  ZWE  2013  1820.090331                  13108.151347
# 2374     Zimbabwe  ZWE  2014  1769.993458                  12841.510671
# 2375     Zimbabwe  ZWE  2015  1728.691503                  12637.728613
# 2376     Zimbabwe  ZWE  2016  1703.437894                  12495.147292
# 2377     Zimbabwe  ZWE  2017  1677.007331                  12369.654705
#
#       Intestinal infectious diseases  Protein-energy malnutrition  Terrorism  \
# ...

# %%
info_columns = ["Entity", "Code", "Year"]

# %% [markdown]
# ### Extract world data

# %%
world_death_df = extract_world_data(death_df)
world_death_df
# Out:
#   Entity      Code  Year     Meningitis  Lower respiratory infections  \
# 0  World  OWID_WRL  2008  348040.083847                  2.657275e+06
# 1  World  OWID_WRL  2009  340514.177436                  2.639562e+06
# 2  World  OWID_WRL  2010  331205.914662                  2.623649e+06
# 3  World  OWID_WRL  2011  325000.383494                  2.616651e+06
# 4  World  OWID_WRL  2012  316965.020009                  2.605154e+06
# 5  World  OWID_WRL  2013  312013.523643                  2.590482e+06
# 6  World  OWID_WRL  2014  306484.322622                  2.579538e+06
# 7  World  OWID_WRL  2015  298711.517721                  2.582199e+06
# 8  World  OWID_WRL  2016  295878.990018                  2.574625e+06
# 9  World  OWID_WRL  2017  288021.105387                  2.558606e+06
#
#    Intestinal infectious diseases  Protein-energy malnutrition  Terrorism  \
# 0                   176583.045171                304321.884855     9157.0
# ...

# %% [markdown]
# ### Predict NaN value

# %%
intestine_col = "Intestinal infectious diseases"
intestine_data = list(world_death_df[intestine_col])[:-1]
intestine_pred_data = [[i+2008, x] for i, x in enumerate(intestine_data)]

X = np.array(intestine_pred_data)[:,0].reshape(-1,1)
y = np.array(intestine_pred_data)[:,1].reshape(-1,1)

to_predict_x= 2017
to_predict_x= np.array(to_predict_x).reshape(-1,1)

regsr = LinearRegression()
regsr.fit(X,y)
predicted_y = regsr.predict(to_predict_x)

m = regsr.coef_
c = regsr.intercept_

# %%
plt.title('Predict 2017 death toll for Intestinal infectious diseases')  
plt.xlabel('Year')  
plt.ylabel('Deaths') 
plt.scatter(X,y,color="blue")
new_y = [m*i+c for i in np.append(X, to_predict_x)]
new_y = np.array(new_y).reshape(-1,1)
plt.scatter(X,y,color="blue")
plt.scatter(to_predict_x, predicted_y, color="green")
plt.plot(np.append(X,to_predict_x),new_y,color="red")
plt.show()

# %%
world_death_df.at[9, intestine_col] = predicted_y
world_death_df
# Out:
#   Entity      Code  Year     Meningitis  Lower respiratory infections  \
# 0  World  OWID_WRL  2008  348040.083847                  2.657275e+06
# 1  World  OWID_WRL  2009  340514.177436                  2.639562e+06
# 2  World  OWID_WRL  2010  331205.914662                  2.623649e+06
# 3  World  OWID_WRL  2011  325000.383494                  2.616651e+06
# 4  World  OWID_WRL  2012  316965.020009                  2.605154e+06
# 5  World  OWID_WRL  2013  312013.523643                  2.590482e+06
# 6  World  OWID_WRL  2014  306484.322622                  2.579538e+06
# 7  World  OWID_WRL  2015  298711.517721                  2.582199e+06
# 8  World  OWID_WRL  2016  295878.990018                  2.574625e+06
# 9  World  OWID_WRL  2017  288021.105387                  2.558606e+06
#
#    Intestinal infectious diseases  Protein-energy malnutrition  Terrorism  \
# 0                   176583.045171                304321.884855     9157.0
# ...

# %%
tot_columns = list(world_death_df.columns)
cause_columns = [e for e in tot_columns if e not in info_columns]

# %%
world_death_per_million_df = divide_values_by_pop(world_death_df, cause_columns)
world_death_per_million_df
# Out:
#   Entity      Code  Year  Meningitis  Lower respiratory infections  \
# 0  World  OWID_WRL  2008   51.264625                    391.403765
# 1  World  OWID_WRL  2009   49.545427                    384.060990
# 2  World  OWID_WRL  2010   47.608784                    377.133226
# 3  World  OWID_WRL  2011   46.156998                    371.620363
# 4  World  OWID_WRL  2012   44.481150                    365.593101
# 5  World  OWID_WRL  2013   43.271614                    359.261188
# 6  World  OWID_WRL  2014   42.011255                    353.589437
# 7  World  OWID_WRL  2015   40.476929                    349.901081
# 8  World  OWID_WRL  2016   39.640691                    344.938041
# 9  World  OWID_WRL  2017   38.159312                    338.984354
#
#    Intestinal infectious diseases  Protein-energy malnutrition  Terrorism  \
# 0                       26.009830                    44.825145   1.348782
# 1                       25.280311                    43.252385   1.349238
# ...

# %% [markdown]
# ## Categorised deaths

# %%
cat_death_df = modify_and_drop_cols(raw_cat_death_df, {}, [])
cat_death_df
# Out:
#            Entity Code  Year  Non-communicable diseases  \
# 0     Afghanistan  AFG  2008              107108.631648
# 1     Afghanistan  AFG  2009              106507.662016
# 2     Afghanistan  AFG  2010              106608.183852
# 3     Afghanistan  AFG  2011              107238.990094
# 4     Afghanistan  AFG  2012              107575.457736
# ...           ...  ...   ...                        ...
# 2305     Zimbabwe  ZWE  2013               43813.657226
# 2306     Zimbabwe  ZWE  2014               43708.402562
# 2307     Zimbabwe  ZWE  2015               43853.733855
# 2308     Zimbabwe  ZWE  2016               44364.468727
# 2309     Zimbabwe  ZWE  2017               44899.862604
#
#       Communicable, maternal, neonatal, and nutritional diseases      Injuries
# 0                                         102268.763448           29830.866176
# 1                                          99423.405087           30147.362477
# ...

# %% [markdown]
# ### Extract world data

# %%
world_cat_death_df = extract_world_data(cat_death_df)
world_cat_death_df
# Out:
#   Entity      Code  Year  Non-communicable diseases  \
# 0  World  OWID_WRL  2008               3.418150e+07
# 1  World  OWID_WRL  2009               3.483548e+07
# 2  World  OWID_WRL  2010               3.559222e+07
# 3  World  OWID_WRL  2011               3.621622e+07
# 4  World  OWID_WRL  2012               3.683037e+07
# 5  World  OWID_WRL  2013               3.735997e+07
# 6  World  OWID_WRL  2014               3.825766e+07
# 7  World  OWID_WRL  2015               3.945300e+07
# 8  World  OWID_WRL  2016               4.040355e+07
# 9  World  OWID_WRL  2017               4.107113e+07
#
#    Communicable, maternal, neonatal, and nutritional diseases      Injuries
# 0                                       1.308734e+07           4.634715e+06
# 1                                       1.281121e+07           4.425399e+06
# 2                                       1.252802e+07           4.718076e+06
# 3                                       1.219007e+07           4.487698e+06
# ...

# %%
cat_all_columns = list(world_cat_death_df.columns)
cat_columns = [e for e in cat_all_columns if e not in info_columns]

# %%
world_cat_death_per_million_df = divide_values_by_pop(world_cat_death_df, cat_columns)
world_cat_death_per_million_df
# Out:
#   Entity      Code  Year  Non-communicable diseases  \
# 0  World  OWID_WRL  2008                5034.770346
# 1  World  OWID_WRL  2009                5068.625892
# 2  World  OWID_WRL  2010                5116.159032
# 3  World  OWID_WRL  2011                5143.477586
# 4  World  OWID_WRL  2012                5168.574717
# 5  World  OWID_WRL  2013                5181.268983
# 6  World  OWID_WRL  2014                5244.158243
# 7  World  OWID_WRL  2015                5346.081861
# 8  World  OWID_WRL  2016                5413.106459
# 9  World  OWID_WRL  2017                5441.428361
#
#    Communicable, maternal, neonatal, and nutritional diseases    Injuries
# 0                                        1927.702704           682.671095
# 1                                        1864.054122           643.903534
# 2                                        1800.824760           678.193927
# 3                                        1731.250708           637.349036
# ...

# %% [markdown]
# # Plotting

# %%
def plot_line_chart(df, x_axis, y_axis, y_label, title, y_start_0 = False):
    """
    Will extract 7 random elements from y_axis if len(y_axis) > 7
    """
    if len(y_axis) > 7:
        y_axis = random.sample(y_axis, 7)
    ax = plt.gca()
    for i, col in enumerate(y_axis):
        df.plot(kind='line', x=x_axis, y=col, ax=ax, color=COLORS[i%len(COLORS)], logy=True, title=title, xlabel=x_axis, ylabel=y_label)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    if y_start_0:
        ax.set_ylim(ymin=1)
    plt.xlabel = x_axis
    plt.ylabel = y_label
    plt.title = title
    plt.show()

# %%
def plot_stacked_area_chart(df, x_axis, y_axis, y_label, title):
    df = df[y_axis +[x_axis]]
    ax = df.plot.area(x=x_axis)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.xlabel = x_axis
    plt.ylabel = y_label
    plt.title = title
    plt.show()

# %% [markdown]
# ## Total deaths

# %%
plot_line_chart(world_death_df, "Year", cause_columns, "Deaths", "Number of deaths by cause")

# %%
plot_line_chart(world_death_per_million_df, "Year", cause_columns, "Deaths", "Number of deaths by cause per million")

# %% [markdown]
# ## Categorical deaths

# %%
plot_stacked_area_chart(world_cat_death_df, "Year", cat_columns, "", "Number of deaths by category")

# %%
plot_stacked_area_chart(world_cat_death_per_million_df, "Year", cat_columns, "", "Number of deaths by category per million")
